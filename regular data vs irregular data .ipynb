# %%
import random
randomlist =random.sample(range(30), 10)
print(randomlist)
# Out:
# [10, 11, 29, 12, 23, 3, 24, 14, 18, 4]

# %%
import numpy as np
import pandas as pd
a = 10*randomlist
a = np. array(a)
a
# Out:
# array([10, 11, 29, 12, 23,  3, 24, 14, 18,  4, 10, 11, 29, 12, 23,  3, 24,
#        14, 18,  4, 10, 11, 29, 12, 23,  3, 24, 14, 18,  4, 10, 11, 29, 12,
#        23,  3, 24, 14, 18,  4, 10, 11, 29, 12, 23,  3, 24, 14, 18,  4, 10,
#        11, 29, 12, 23,  3, 24, 14, 18,  4, 10, 11, 29, 12, 23,  3, 24, 14,
#        18,  4, 10, 11, 29, 12, 23,  3, 24, 14, 18,  4, 10, 11, 29, 12, 23,
#         3, 24, 14, 18,  4, 10, 11, 29, 12, 23,  3, 24, 14, 18,  4])

# %%
b = []
for i in range(0,100):
 n2 = random.randint(1,30)
 b.append(n2)
print(b)
# Out:
# [9, 14, 15, 17, 25, 6, 27, 14, 3, 18, 16, 1, 18, 4, 14, 28, 24, 21, 8, 11, 8, 9, 3, 30, 28, 29, 3, 3, 9, 22, 19, 4, 29, 3, 22, 12, 19, 28, 14, 2, 6, 21, 15, 2, 4, 19, 30, 26, 15, 3, 2, 27, 4, 30, 17, 9, 10, 10, 21, 5, 18, 19, 19, 21, 20, 8, 6, 6, 5, 14, 14, 4, 2, 26, 14, 5, 14, 9, 6, 28, 4, 8, 27, 14, 26, 14, 27, 14, 18, 5, 21, 6, 5, 26, 26, 1, 5, 25, 21, 15]

# %%
import matplotlib.pyplot as plt

# %%
#ploting a histogram for a:
plt.style.use('ggplot')
plt.hist(a, bins=30)
plt.xlabel('10 Randomly Generated Numbers from 1 to 30 Reapeted 10 Times')
plt.ylabel("Frequency of Each Number")
# Out:
# Text(0, 0.5, 'Frequency of Each Number')

# %%
#ploting a histogram for a:
plt.style.use('ggplot')
plt.hist(b, bins=30)
plt.xlabel('100 Randomly Generated Numbers from 1 to 30')
plt.ylabel("Frequency of Each Number")
# Out:
# Text(0, 0.5, 'Frequency of Each Number')
