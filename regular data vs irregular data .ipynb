# %%
import random
randomlist = []
for i in range(0,10):
 n = random.randint(1,30)
 randomlist.append(n)
print(randomlist)
# Out:
# [9, 6, 16, 20, 11, 12, 14, 22, 13, 11]

# %%
import numpy as np
import pandas as pd
a = 10*randomlist
a = np. array(a)
a
# Out:
# array([ 9,  6, 16, 20, 11, 12, 14, 22, 13, 11,  9,  6, 16, 20, 11, 12, 14,
#        22, 13, 11,  9,  6, 16, 20, 11, 12, 14, 22, 13, 11,  9,  6, 16, 20,
#        11, 12, 14, 22, 13, 11,  9,  6, 16, 20, 11, 12, 14, 22, 13, 11,  9,
#         6, 16, 20, 11, 12, 14, 22, 13, 11,  9,  6, 16, 20, 11, 12, 14, 22,
#        13, 11,  9,  6, 16, 20, 11, 12, 14, 22, 13, 11,  9,  6, 16, 20, 11,
#        12, 14, 22, 13, 11,  9,  6, 16, 20, 11, 12, 14, 22, 13, 11])

# %%
b = []
for i in range(0,100):
 n2 = random.randint(1,30)
 b.append(n2)
print(b)
# Out:
# [23, 9, 28, 4, 28, 22, 14, 15, 11, 2, 22, 2, 6, 18, 28, 11, 28, 15, 16, 26, 4, 2, 12, 11, 15, 7, 2, 19, 8, 2, 8, 22, 27, 1, 29, 17, 16, 1, 10, 24, 18, 24, 11, 19, 6, 10, 2, 8, 24, 9, 1, 29, 25, 1, 27, 5, 26, 20, 18, 7, 23, 26, 12, 21, 2, 18, 15, 28, 22, 17, 26, 15, 19, 17, 26, 17, 23, 6, 20, 7, 12, 10, 17, 26, 24, 19, 4, 12, 9, 24, 11, 9, 19, 13, 13, 15, 17, 18, 26, 7]

# %%
import matplotlib.pyplot as plt

# %%
#ploting a histogram for a:
plt.style.use('ggplot')
plt.hist(a, bins=10)
plt.xlabel('10 Randomly Generated Numbers from 1 to 30 Reapeted 10 Times')
plt.ylabel("Frequency of Each Number")
# Out:
# Text(0, 0.5, 'Frequency of Each Number')

# %%
#ploting a histogram for a:
plt.style.use('ggplot')
plt.hist(b, bins=10)
plt.xlabel('100 Randomly Generated Numbers from 1 to 30')
plt.ylabel("Frequency of Each Number")
# Out:
# Text(0, 0.5, 'Frequency of Each Number')
